# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('Dataset/Leads_cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                           Prospect ID  Lead Number  \
# 0           0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1           1  2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2           2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3           3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4           4  3256f628-e534-4826-9d63-4a8b88782852       660681
#
#                Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                      API      Olark Chat           No          No
# 1                      API  Organic Search           No          No
# 2  Landing Page Submission  Direct Traffic           No          No
# 3  Landing Page Submission  Direct Traffic           No          No
# 4  Landing Page Submission          Google           No          No
#
#    Converted  TotalVisits  Total Time Spent on Website  ...  \
# 0          0          0.0                            0  ...
# ...

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'City', 'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
len(df['Lead Source'].unique())
# Out:
# 21

# %%
plt.figure(figsize=(15,10))
plt.title('Lead source vs Converted')
sns.countplot(y=df['Lead Source'], hue=df['Converted'])
plt.show()
plt.savefig('Lead Source vs Converted')

# %% [markdown]
# Inferences: There are notable observations
#
# 1. Top 3 sources are Google, Direct Traffic and Organic Search. So they should really focus on SEO and SMO also UX
# 2. Lead Source is definitely a deciding factor

# %%
len(df['Lead Origin'].unique())
# Out:
# 5

# %%
def Catplotting(x):
    plt.figure(figsize=(15,10))
    name = x+'Vs Converted'
    plt.title(name)
    
    sns.countplot(y=df[x], hue=df['Converted'])
    
    plt.savefig(name)
    plt.show()

# %%
Catplotting('Lead Origin')

# %% [markdown]
# Infrence: Following infrences can be drawn
# 1. They should really improve their landing page as it looks like their main soource
# 2. Working on API wouldn't hurt as well
# 3. Important feature for prediction

# %%
Catplotting('Lead Quality')

# %% [markdown]
# Infrences: Following are the observations:
# 1. High in relevance, Might be and Low in relevance are comparitively much better performers
# 2. Deciding feature

# %%
Catplotting('City')

# %% [markdown]
# Infrence:
# 1. Mumbai is the driving city for their business right now so they should increase user retention here
# 2. They should work on their campaigns for thane, next promising city
# 3. Other metro cities might be a good expansion
# 4. Deciding Feature

# %%
Catplotting('Through Recommendations')

# %% [markdown]
# Infrence:
# 1. Data reflects that almost no lead was converted via recommendation
# 2. We can drop this feature

# %%
Catplotting('Magazine')

# %% [markdown]
# Infrence:
# 1. There's no 'Yes' in magazine feature
# 2. Safe to drop feature

# %%
Catplotting('Newspaper Article')

# %% [markdown]
# Infrence:
# 1. Almost no value in newspaper as 'yes'
# 2. Safe to drop feature

# %%
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'City', 'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
Catplotting('A free copy of Mastering The Interview')

# %% [markdown]
# Infrences:
# 1. People who don't opt for interview copies still have better conversion rates
# 2. Deciding Features

# %%
Catplotting('Do Not Email')

# %% [markdown]
# Infrences:
# 1. People who don't opt for emails are the real buyers
# 2. Deciding Factor

# %%
Catplotting('Digital Advertisement')

# %% [markdown]
# Infrences:
# 1. Either they are not advertising at all or their campaign is really not working
# 2. Safe to drop this feature

# %%
Catplotting('Tags')

# %% [markdown]
# Infrences:
# 1. Tags are subjective choices and our effort is to save time in taggig and following by giving a lead score
# 2. Safe to drop

# %%
Catplotting('Do Not Call')

# %% [markdown]
# Infrences:
# 1. No one has opted or given a sale by opting for a call so its better not to consider it

# %%
len(df['Search'].unique())
# Out:
# 2

# %%
Catplotting('Search')

# %% [markdown]
# Infrence:
# 1. Safe to drop

# %%
Catplotting('What matters most to you in choosing a course')

# %% [markdown]
# Infrence:
# 1. No one has chosen other options
# 2. Doesn't really affecting the predictions
# 3. Safe to drop

# %%
plt.figure(figsize=(15,10))

name = 'Total Visits vs Converted'
plt.title('Total Visits vs Converted')

sns.lineplot(data=df,x = df['TotalVisits'],y=df['Converted'])

plt.savefig(name)

plt.show()

# %% [markdown]
# Infrence:
# 1. People who spend more than 150 units of time ends up being the buyer
# 2. Influential Feature

# %%
plt.figure(figsize=(15,10))

name = 'Total Visits vs Converted'
plt.title('Total Visits vs Converted')

sns.scatterplot(data=df,x = df['TotalVisits'],y=df['Converted'])

plt.savefig(name)

plt.show()

# %%
 df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'City', 'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
def cvrplot(x):
    plt.figure(figsize=(10,10))
    
    name = x + ' Vs Converted'
    plt.title(name)
    
    
    chart = sns.lineplot(x = df[x],y=df['Converted'])
    chart.set_xticklabels(rotation=90, horizontalalignment='right')
    plt.savefig(name)

# %%
def cvrscatplot(x):
    
    name = x + ' Vs Converted'
    plt.title(name)
    
    sns.scatterplot(data=df,x = df[x],y=df['Converted'])

    
    
    
    plt.savefig(name)

# %%
cvrplot('Total Time Spent on Website')

# %% [markdown]
# Infrence:
#
# 1. It is an important feature

# %%
cvrplot('Page Views Per Visit')

# %%
cvrscatplot('Page Views Per Visit')

# %% [markdown]
# Infrence:
# 1. People who spend more time than 30 visits don't end up being converted
# 2. Important Feature

# %%
Catplotting('Last Activity')

# %% [markdown]
# Infrence:
# 1. Best conversion comes from sms and mails
# 2. Influential feature

# %%
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'City', 'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
columns = ['Lead Origin',
           'Lead Source',
           'TotalVisits',
           'Total Time Spent on Website',
           'Page Views Per Visit',
           'Last Activity',
           'Lead Quality',
           'City',
           'Last Notable Activity',
           'A free copy of Mastering The Interview',
           'Do Not Email',
          'Converted']

# %%
df_matters = df[columns]

# %%
df_matters
# Out:
#                   Lead Origin     Lead Source  TotalVisits  \
# 0                         API      Olark Chat          0.0
# 1                         API  Organic Search          5.0
# 2     Landing Page Submission  Direct Traffic          2.0
# 3     Landing Page Submission  Direct Traffic          1.0
# 4     Landing Page Submission          Google          2.0
# ...                       ...             ...          ...
# 9235  Landing Page Submission  Direct Traffic          8.0
# 9236  Landing Page Submission  Direct Traffic          2.0
# 9237  Landing Page Submission  Direct Traffic          2.0
# 9238  Landing Page Submission          Google          3.0
# 9239  Landing Page Submission  Direct Traffic          6.0
#
#       Total Time Spent on Website  Page Views Per Visit  \
# 0                               0                  0.00
# 1                             674                  2.50
# 2                            1532                  2.00
# ...

# %%
df_matters.dtypes
df_matters.to_csv('Processed.csv')
df_matters.dtypes
# Out:
# Lead Origin                                object
# Lead Source                                object
# TotalVisits                               float64
# Total Time Spent on Website                 int64
# Page Views Per Visit                      float64
# Last Activity                              object
# Lead Quality                               object
# City                                       object
# Last Notable Activity                      object
# A free copy of Mastering The Interview     object
# Do Not Email                               object
# Converted                                   int64
# dtype: object

# %% [markdown]
# # We will do numeric encoding for all the categorical values present so that we can better utilise the features

# %%
from sklearn.preprocessing import LabelEncoder
df_matters['City_encoded'] = LabelEncoder().fit_transform(df_matters['City'])
df_matters[['City', 'City_encoded']] # special syntax to get just these two colum
# Out:
# C:\Users\91847\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     City  City_encoded
# 0                 Mumbai             0
# 1                 Mumbai             0
# 2                 Mumbai             0
# 3                 Mumbai             0
# 4                 Mumbai             0
# ...                  ...           ...
# 9235              Mumbai             0
# 9236              Mumbai             0
# 9237              Mumbai             0
# 9238  Other Metro Cities             3
# 9239        Other Cities             1
#
# [9240 rows x 2 columns]
